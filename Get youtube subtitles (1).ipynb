# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.3.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in c:\users\parth\appdata\roaming\python\python38\site-packages (from youtube-transcript-api) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\parth\appdata\roaming\python\python38\site-packages (from requests->youtube-transcript-api) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\parth\appdata\roaming\python\python38\site-packages (from requests->youtube-transcript-api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parth\appdata\roaming\python\python38\site-packages (from requests->youtube-transcript-api) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\parth\appdata\roaming\python\python38\site-packages (from requests->youtube-transcript-api) (1.25.10)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
 subtitles=YouTubeTranscriptApi.get_transcript('ygUqvfeAaa0')#https://youtu.be/JkaxUblCGz0https://www.youtube.com/watch?v=

# %%
print(subtitles)
# Out:
# [{'text': '( Okay, Matias: Radio check, radio check. )', 'start': 5.133, 'duration': 2.3}, {'text': '( Copy. Loud and clear. )', 'start': 8.767, 'duration': 1.166}, {'text': '( Okay, start the engine! )', 'start': 11.733, 'duration': 1.734}, {'text': '( George you can switch to map 5, map 5. )', 'start': 23.133, 'duration': 2.934}, {'text': '( And go! )', 'start': 27.0, 'duration': 0.667}, {'text': 'I find it surprising that this kind of place\nstill exists in the world,', 'start': 37.133, 'duration': 3.367}, {'text': 'a place for adults who want to be challenged.', 'start': 40.933, 'duration': 2.967}, {'text': 'You just really have to focus on the moment.', 'start': 45.3, 'duration': 1.533}, {'text': "If you start to think about the race or how it's gonna end,", 'start': 46.833, 'duration': 3.0}, {'text': 'you just have to take it one thing at the time,\nbring the car forward', 'start': 50.0, 'duration': 3.9}, {'text': 'second by second, minute by minute', 'start': 53.9, 'duration': 1.867}, {'text': "at some point you're going to see the checker flag.", 'start': 56.167, 'duration': 1.433}, {'text': "What I've been seeking to figure out through this,", 'start': 64.467, 'duration': 1.833}, {'text': 'is what sort of car the modern day sports car is,', 'start': 66.633, 'duration': 7.167}, {'text': 'and I drove the M6 as a part of that search.', 'start': 74.4, 'duration': 4.0}, {'text': 'We make video games,', 'start': 78.833, 'duration': 3.267}, {'text': "but it's really important to know the real thing.", 'start': 82.1, 'duration': 2.633}, {'text': "And racing, I think it's the same with anything,", 'start': 86.267, 'duration': 3.233}, {'text': "but you can't know the real thing\nuntil you've experienced it yourself.", 'start': 89.5, 'duration': 3.967}, {'text': 'And if you are going to experience something,', 'start': 93.933, 'duration': 2.167}, {'text': 'you might as well experience the most incredible.', 'start': 96.633, 'duration': 1.934}, {'text': "What's special for me about this race and this team is", 'start': 100.833, 'duration': 2.5}, {'text': "that it's backed by PlayStation and Gran Turismo.", 'start': 103.333, 'duration': 2.267}, {'text': 'And the fact that I get to drive with Kazunori,\nwhich is one of my childhood heroes.', 'start': 106.2, 'duration': 4.933}, {'text': "I can remember, I think it was '96 or '97\nwhen the first Gran Turismo came out", 'start': 111.4, 'duration': 4.1}, {'text': 'and I played it for hours at the time and ', 'start': 116.367, 'duration': 2.133}, {'text': 'for me being part of the PlayStation\nand the Gran Turismo team is really special. ', 'start': 118.9, 'duration': 3.7}, {'text': 'With the game being so big the affiliation \nthat people have towards the sponsorship of our car', 'start': 123.067, 'duration': 5.966}, {'text': 'and Kazunori - driving with him has been\na really interesting experience for all of us.', 'start': 129.233, 'duration': 5.8}, {'text': "And, you know, he's a god in many respects for gamers.", 'start': 135.533, 'duration': 4.167}, {'text': "And not that I'm an avid gamer but,\nyou know I understand, I think,", 'start': 139.767, 'duration': 5.933}, {'text': 'his presence in the paddock from that point of view.', 'start': 145.7, 'duration': 3.1}, {'text': "And that's been pretty special, yeah.", 'start': 148.867, 'duration': 3.1}, {'text': 'The M has done a fantastic job.\nThey developed a great engine', 'start': 156.667, 'duration': 3.466}, {'text': 'and in the M6 GT3 the production engine\nactually was taken over practically to 95%.', 'start': 160.133, 'duration': 7.434}, {'text': 'Also the longer wheelbase, the aerodynamics,\nthe better flow towards the rear-wing,', 'start': 167.567, 'duration': 3.366}, {'text': 'all those were factors for deciding that\nthe M6 as a base car fits really really well.', 'start': 170.933, 'duration': 4.4}, {'text': 'And the development process then\nwas to look at the series vehicle,', 'start': 175.333, 'duration': 4.234}, {'text' ...

# %%
type(subtitles)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.DataFrame(subtitles)
df.head()
# Out:
#                                           text   start  duration
# 0  ( Okay, Matias: Radio check, radio check. )   5.133     2.300
# 1                    ( Copy. Loud and clear. )   8.767     1.166
# 2                  ( Okay, start the engine! )  11.733     1.734
# 3   ( George you can switch to map 5, map 5. )  23.133     2.934
# 4                                  ( And go! )  27.000     0.667

# %%
subtitle_list = df['text'].tolist()
subtitle_list
# Out:
# ['The desert wind whipped up a storm of sand\nthat made keeping cars pointing',
#  'in the right direction a feat of superhuman skill\non the opening day of pre-season testing in Bahrain,',
#  'where there are only three days\nfor teams and drivers to prepare',
#  'everything they need before\nthe first race of the season.',
#  'And it was the Bulls that charged out of the blocks first, \nMax Verstappen picking up',
#  'from where he left off at the end of 2020,',
#  'with his victory in Abu Dhabi,\nhis time of 1:30.412',
#  'was two-tenths of a second quicker than his rivals.',
#  'And he completed a mammoth 139 laps ',
#  'to show that Red Bull have the reliability \nto match their speed,',
#  'a whole two and a half Grand Prix distances.',
#  "McLaren's Lando Norris was second fastest",
#  'in a strong showing, \nwhile his new team-mate Daniel Ricciardo kicked off ',
#  'his McLaren career with a solid seventh place.',
#  'Esteban Ocon had a mighty day for Alpine,\nthe rebranded Renault outfit, ',
#  'four tenths back from Verstappen, \nbut posting 129 laps in an epic effort.',
#  '- "Very, very productive day, that\'s for sure.',
#  'We completed the whole programme.',
#  'No reliability issue, \njust working on what we wanted, basically, ',
#  'to get ready for the first weekend \nand, yeah, all fine so far.',
#  'Following multiple years of metronomic reliability, ',
#  'it was a shock to see\nreigning champions Mercedes struggle,',
#  'Valtteri Bottas limping back to the pits',
#  'with just a single installation lap under his belt,\nand a gearbox change restricting the Finn',
#  'to just six timed laps before the lunch break.',
#  '- "Six total laps, all with aero rakes in the car,',
#  'so not too much running today.',
#  'So not an ideal start."',
#  'Lewis Hamilton took over the wheel for the afternoon,',
#  'but uncharacteristically struggled for grip.',
#  'Only tenth quickest for the reigning world champion.',
#  'Ferrari are hoping a new power unit can\nrevive their fortunes after falling to',
#  "sixth in last year's constructors' championship.",
#  'Charles Leclerc was running solidly\nbefore a power unit issue',
#  'brought his progress to a halt\nat the end of the morning session.',
#  "Carlos Sainz's debut in red was smooth, though,",
#  'with a consistent afternoon seeing him end fifth fastest',
#  'despite a spin at Turn 11.',
#  'Sebastian Vettel shared driving duties for Aston Martin ',
#  'in the Racing Green AMR21\nbefore Lance Stroll took over ',
#  'for the afternoon session and went fourth fastest.\nMick Schumacher returned the famous surname',
#  'to the F1 timesheets for the first time \nin eight years, but gearbox issues',
#  'meant he managed just 15\nlaps for new employers Haas,',
#  'the American team running\ntwo rookie drivers this season,',
#  'with Nikita Mazepin posting\na healthier lap count of 70.',
#  "2021's third rookie, Yuki Tsunoda, \nhad a decent day in the AlphaTauri, ",
#  'fractionally slower than team-mate \nand Bahrain specialist Pierre Gasly,',
#  'but both drivers inside the top ten.',
#  'Alfa Romeo completed the second-most laps on day one, \nwith Kimi Raikkonen and Antonio Giovinazzi',
#  'splitting driving duties\nin the absence of their team principal Fred Vasseur,',
#  "who's at home recovering from Covid-19.\nBut he'll have been cheered to see 131 laps",
#  'on the board and Giovinazzi\nflying high on the timesheets.',
#  'P6 for the Italian beginning his third\nfull season in Formula 1.',
#  'And Williams test driver Roy Nissany had\nday one to himself in the FW43B, ',
#  'posting 83 laps as part of a solid start ',
#  'before race drivers Nicholas Latifi and George Russell\ntake over for days two and three.',
#  "We haven't seen the ultimate pace of any",
#  'of the new cars yet, \nbut the first leaderboard of 2021 makes for ',
#  'interesting reading, with youth on top: \nVerstappen from Norris, Ocon, Stroll and Sainz, ',
#  'Giovinazzi, the two AlphaTauris and \nLewis Hamilton rounding out the top ten.',
#  'Charles Leclerc, Kimi Raikkonen and Sebastian Vettel',
#  'were next up, with Nissany\nSchumacher, Mazepin and the unlucky Bottas',
#  'completing the timesheets.\nOne day down, two to go!',
#  'F1 2021 is here.']

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PARTH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
ps=PorterStemmer()
corpus=[]
for i in range(0,len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PARTH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
ps=WordNetLemmatizer()
corpus=[]
for i in range(0,len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    review = review.lower()
    review = review.split()
    review = [ps.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
corpus
# Out:
# ['okay matias radio check radio check',
#  'copy loud clear',
#  'okay start engine',
#  'george switch map map',
#  'go',
#  'find surprising kind place still exists world',
#  'place adult want challenged',
#  'really focus moment',
#  'start think race gonna end',
#  'take one thing time bring car forward',
#  'second second minute minute',
#  'point going see checker flag',
#  'seeking figure',
#  'sort car modern day sport car',
#  'drove part search',
#  'make video game',
#  'really important know real thing',
#  'racing think anything',
#  'know real thing experienced',
#  'going experience something',
#  'might well experience incredible',
#  'special race team',
#  'backed playstation gran turismo',
#  'fact get drive kazunori one childhood hero',
#  'remember think first gran turismo came',
#  'played hour time',
#  'part playstation gran turismo team really special',
#  'game big affiliation people towards sponsorship car',
#  'kazunori driving really interesting experience u',
#  'know god many respect gamers',
#  'avid gamer know understand think',
#  'presence paddock point view',
#  'pretty special yeah',
#  'done fantastic job developed great engine',
#  'gt production engine actually taken practically',
#  'also longer wheelbase aerodynamics better flow towards rear wing',
#  'factor deciding base car fit really really well',
#  'development process look series vehicle',
#  'year new regulation gt',
#  'occupied intensively finding best package',
#  'mechanically aerodynamically originated',
#  'gt class mainly differentiated racing car homologated',
#  'mean continuous improvement vehicle season allowed',
#  'smaller change homologated subsequently',
#  'larger development step permitted side fia',
#  'background trying modify near series vehicle way racing car come',
#  'done reasonably cost efficient achieve comparability different manufacturer',
#  'general mentioned current vehicle gt class',
#  'completely new generation vehicle',
#  'broader track width allowed mean vehicle become generally wider',
#  'side kinematics longer tied serial production',
#  'got technical support bmw christian kuhnke travelling u',
#  'car whole season lively exchange',
#  'also always involved technician',
#  'suspension engineer technical engineer concerning support chassis adjustment',
#  'car n rburgring think car number sensor built',
#  'recorded data logger also sent wireless telemetry system',
#  'received real time pit analyzed spot',
#  'data fed gran turismo simulation like simulator',
#  'make sure real car movement track',
#  'movement car gran turismo match properly',
#  'test aragon enormously important u also partner dunlop tire',
#  'relatively new say tire size driven front back tire',
#  'type tire term structure technique term width size',
#  'first learn work towards tire work car',
#  'specifically drove aragon layout track offered u certain advantage',
#  'long straight fast curve',
#  'want compare nordschleife',
#  'least requirement profile tire pretty identical',
#  'tire made pc like many thing nowadays everything calculated',
#  'course difference product tire actually function',
#  'connection car street',
#  'n rburgring particular special challenge course',
#  'term physical design car large',
#  'almost mechanical beauty',
#  'chunky chunky line like',
#  'huge air intake front stuff like',
#  'attractive car think robust well',
#  'design jawbreaker done j p kraemer',
#  'acknowledged designer also car fanatic',
#  'also z last year second one also interesting',
#  'sony playstation car call',
#  'completely new foil car reflects strongly',
#  'enormous amount pixel come incredibly clear photographer',
#  'think design speaks make good impression',
#  'first time saw looked like something video game really like',
#  'cool',
#  'participating vln race extremely important need gain experience car',
#  'also track driver need certain amount lap feel comfortable inside car',
#  'indeed know beforehand turn left right',
#  'every car reacts differently curb like',
#  'especially setup finding development tire',
#  'warm whole team important',
#  'participate possible event reel kilometer',
#  'optimally prepared h race',
#  'h qualifying h race really important',
#  'especially team sp class thus gt class',
#  'rule qualifying identical h race',
#  'mean kind general rehearsal team',
#  'detail bit different normal vln run happy say',
#  'reeling kilometer gaining experience',
#  'place german automotive culture place automobile started',
#  'symbol german automotive culture',
#  'massive track length km',
#  'fact exists incredible',
#  'also car racing hundred thousand spectator',
#  'everything quite beyond norm',
#  'mecca car people',
#  'know people watching obscure place track',
#  'hundred change direction one lap',
#  'lap take minute obviously',
#  'nowhere near close anywhere else world',
#  'combine car let say n rburgring h',
#  'combine terrible weather get eifel',
#  'think really amount major appeal even racing',
#  'know really fallen love whole thing',
#  'add uniqueness n rburgring h',
#  'far hardest race probably interesting also',
#  'prestige race see',
#  'think acknowledged one hardest race worldwide concerning material',
#  'demanded product car',
#  'certainly germany related would say fact international stage',
#  'whoever able experience enters starting grid saturday',
#  'vast crowd people nearly unable get car',
#  'well kind tickling feeling',
#  'sitting driver team manager directly car',
#  'even spectator somehow like community tingle little everyone',
#  'especially wonderful get really close track',
#  'really experiencing motor sport close',
#  'defines distinctiveness n rburgring',
#  'seriously best feeling three driver',
#  'really like know great feeling',
#  'perfect lap driver always requires grain luck',
#  'lap somehow different',
#  'really rare occasion call perfect lap afterwards',
#  'well like prepare everything prepare nothing',
#  'arriving driver',
#  'got really everything rubber boot flip flop short fur coat',
#  'think interesting',
#  'thought driven',
#  'much downforce first imagined',
#  'downforce stabilizes car faster go',
#  'level difficult match sens car capability',
#  'place used recognize corner track longer corner',
#  'surprise',
#  'personally find really beautiful evening driving night',
#  'camp fire rocket light',
#  'opel club bmw club ford club porsche club',
#  'every time bmw drive past',
#  'sitting bmw rocket flare gun fired',
#  'every lap know',
#  'hour long really sitting car goose bump',
#  'recommend anyone experienced yet',
#  'want drive racing car',
#  'least come track experience view fan',
#  'driver night stint amazing thing see windscreen',
#  'like movie believe true',
#  'really special h race get nordschleife night',
#  'fan light party',
#  'ok take look telemetry data',
#  'copy low battery low battery',
#  'matias drive slowly box drive slowly box',
#  'think game',
#  'super job guy super job',
#  'early morning hour latest around midday see going',
#  'mean everything given car put lot pressure',
#  'lap time reach',
#  'hour hour material also man',
#  'probably imagine going',
#  'special walkenhorst motorsport team',
#  'lot young people operating working together',
#  'extremely exciting extremely important exists strong team feeling',
#  'imagine always hanging around together day night',
#  'use lone fighter people feel team spirit',
#  'extremely strong feature walkenhorst team',
#  'everyone pull direction pull leash',
#  'creates general atmosphere team',
#  'nonetheless everyone extremely much experience position',
#  'absolutely motivated brings maximum performance demand',
#  'reliability simply fantasti lot fun work together guy',
#  'kind create bond really strong',
#  'think something really important take everyone consideration',
#  'team',
#  'data gain one thing really connection people',
#  'fact people connected scene called racing',
#  'think important thing']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cvector = CountVectorizer(min_df = 0.0, max_df = 1.0, ngram_range=(2,3))
cvector.fit(corpus)
# Out:
# CountVectorizer(min_df=0.0, ngram_range=(2, 3))

# %%
cvector1 = CountVectorizer(min_df = 0.0, max_df = 1.0, ngram_range=(1,2))
cvector1.fit(corpus)
cvector1.get_feature_names()
# Out:
# ['able',
#  'able experience',
#  'absolutely',
#  'absolutely motivated',
#  'achieve',
#  'achieve comparability',
#  'acknowledged',
#  'acknowledged designer',
#  'acknowledged one',
#  'actually',
#  'actually function',
#  'actually taken',
#  'add',
#  'add uniqueness',
#  'adjustment',
#  'adult',
#  'adult want',
#  'advantage',
#  'aerodynamically',
#  'aerodynamically originated',
#  'aerodynamics',
#  'aerodynamics better',
#  'affiliation',
#  'affiliation people',
#  'afterwards',
#  'air',
#  'air intake',
#  'allowed',
#  'allowed mean',
#  'almost',
#  'almost mechanical',
#  'also',
#  'also always',
#  'also car',
#  'also interesting',
#  'also last',
#  'also longer',
#  'also man',
#  'also partner',
#  'also sent',
#  'also track',
#  'always',
#  'always hanging',
#  'always involved',
#  'always requires',
#  'amazing',
#  'amazing thing',
#  'amount',
#  'amount lap',
#  'amount major',
#  'amount pixel',
#  'analyzed',
#  'analyzed spot',
#  'anyone',
#  'anyone experienced',
#  'anything',
#  'anywhere',
#  'anywhere else',
#  'appeal',
#  'appeal even',
#  'aragon',
#  'aragon enormously',
#  'aragon layout',
#  'around',
#  'around midday',
#  'around together',
#  'arriving',
#  'arriving driver',
#  'atmosphere',
#  'atmosphere team',
#  'attractive',
#  'attractive car',
#  'automobile',
#  'automobile started',
#  'automotive',
#  'automotive culture',
#  'avid',
#  'avid gamer',
#  'back',
#  'back tire',
#  'backed',
#  'backed playstation',
#  'background',
#  'background trying',
#  'base',
#  'base car',
#  'battery',
#  'battery low',
#  'beautiful',
#  'beautiful evening',
#  'beauty',
#  'become',
#  'become generally',
#  'beforehand',
#  'beforehand turn',
#  'believe',
#  'believe true',
#  'best',
#  'best feeling',
#  'best package',
#  'better',
#  'better flow',
#  'beyond',
#  'beyond norm',
#  'big',
#  'big affiliation',
#  'bit',
#  'bit different',
#  'bmw',
#  'bmw christian',
#  'bmw club',
#  'bmw drive',
#  'bmw rocket',
#  'bond',
#  'bond really',
#  'boot',
#  'boot flip',
#  'box',
#  'box drive',
#  'bring',
#  'bring car',
#  'brings',
#  'brings maximum',
#  'broader',
#  'broader track',
#  'built',
#  'bump',
#  'calculated',
#  'call',
#  'call perfect',
#  'called',
#  'called racing',
#  'came',
#  'camp',
#  'camp fire',
#  'capability',
#  'car',
#  'car call',
#  'car capability',
#  'car come',
#  'car fanatic',
#  'car faster',
#  'car fit',
#  'car forward',
#  'car goose',
#  'car gran',
#  'car homologated',
#  'car large',
#  'car let',
#  'car modern',
#  'car movement',
#  'car number',
#  'car people',
#  'car put',
#  'car racing',
#  'car rburgring',
#  'car reacts',
#  'car reflects',
#  'car street',
#  'car think',
#  'car whole',
#  'certain',
#  'certain advantage',
#  'certain amount',
#  'certainly',
#  'certainly germany',
#  'challenge',
#  'challenge course',
#  'challenged',
#  'change',
#  'change direction',
#  'change homologated',
#  'chassis',
#  'chassis adjustment',
#  'check',
#  'check radio',
#  'checker',
#  'checker flag',
#  'childhood',
#  'childhood hero',
#  'christian',
#  'christian kuhnke',
#  'chunky',
#  'chunky chunky',
#  'chunky line',
#  'class',
#  'class mainly',
#  'class thus',
#  'clear',
#  'clear photographer',
#  'close',
#  'close anywhere',
#  'close track',
#  'club',
#  'club bmw',
#  'club ford',
#  'club porsche',
#  'coat',
#  'combine',
#  'combine car',
#  'combine terrible',
#  'come',
#  'come incredibly',
#  'come track',
#  'comfortable',
#  'comfortable inside',
#  'community',
#  'community tingle',
#  'comparability',
#  'comparability different',
#  'compare',
#  'compare nordschleife',
#  'completely',
#  'completely new',
#  'concerning',
#  'concerning material',
#  'concerning support',
#  'connected',
#  'connected scene',
#  'connection',
#  'connection car',
#  'connection people',
#  'consideration',
#  'continuous',
#  'continuous improvement',
#  'cool',
#  'copy',
#  'copy loud',
#  'copy low',
#  'corner',
#  'corner track',
#  'cost',
#  'cost efficient',
#  'course',
#  'course difference',
#  'create',
#  'create bond',
#  'creates',
#  'creates general',
#  'crowd',
#  'crowd people',
#  'culture',
#  'culture place',
#  'curb',
#  'curb like',
#  'current',
#  'current vehicle',
#  'curve',
#  'data',
#  'data fed',
#  'data gain',
#  'data logger',
#  'day',
#  'day night',
#  'day sport',
#  'deciding',
#  'deciding base',
#  'defines',
#  'defines distinctiveness',
#  'demand',
#  'demanded',
#  'demanded product',
#  'design',
#  'design car',
#  'design jawbreaker',
#  'design speaks',
#  'designer',
#  'designer also',
#  'detail',
#  'detail bit',
#  'developed',
#  'developed great',
#  'development',
#  'development process',
#  'development step',
#  'development tire',
#  'difference',
#  'difference product',
#  'different',
#  'different manufacturer',
#  'different normal',
#  'differentiated',
#  'differentiated racing',
#  'differently',
#  'differently curb',
#  'difficult',
#  'difficult match',
#  'direction',
#  'direction one',
#  'direction pull',
#  'directly',
#  'directly car',
#  'distinctiveness',
#  'distinctiveness rburgring',
#  'done',
#  'done fantastic',
#  'done kraemer',
#  'done reasonably',
#  'downforce',
#  'downforce first',
#  'downforce stabilizes',
#  'drive',
#  'drive kazunori',
#  'drive past',
#  'drive racing',
#  'drive slowly',
#  'driven',
#  'driven front',
#  'driver',
#  'driver always',
#  'driver need',
#  'driver night',
#  'driver team',
#  'driving',
#  'driving night',
#  'driving really',
#  'drove',
#  'drove aragon',
#  'drove part',
#  'dunlop',
#  'dunlop tire',
#  'early',
#  'early morning',
#  'efficient',
#  'efficient achieve',
#  'eifel',
#  'else',
#  'else world',
#  'end',
#  'engine',
#  'engine actually',
#  'engineer',
#  'engineer concerning',
#  'engineer technical',
#  'enormous',
#  'enormous amount',
#  'enormously',
#  'enormously important',
#  'enters',
#  'enters starting',
#  'especially',
#  'especially setup',
#  'especially team',
#  'especially wonderful',
#  'even',
#  'even racing',
#  'even spectator',
#  'evening',
#  'evening driving',
#  'event',
#  'event reel',
#  'every',
#  'every car',
#  'every lap',
#  'every time',
#  'everyone',
#  'everyone consideration',
#  'everyone extremely',
#  'everyone pull',
#  'everything',
#  'everything calculated',
#  'everything given',
#  'everything prepare',
#  'everything quite',
#  'everything rubber',
#  'exchange',
#  'exciting',
#  'exciting extremely',
#  'exists',
#  'exists incredible',
#  'exists strong',
#  'exists world',
#  'experience',
#  'experience car',
#  'experience enters',
#  'experience incredible',
#  'experience position',
#  'experience something',
#  'experience view',
#  'experienced',
#  'experienced yet',
#  'experiencing',
#  'experiencing motor',
#  'extremely',
#  'extremely exciting',
#  'extremely important',
#  'extremely much',
#  'extremely strong',
#  'fact',
#  'fact exists',
#  'fact get',
#  'fact international',
#  'fact people',
#  'factor',
#  'factor deciding',
#  'fallen',
#  'fallen love',
#  'fan',
#  'fan light',
#  'fanatic',
#  'fantasti',
#  'fantasti lot',
#  'fantastic',
#  'fantastic job',
#  'far',
#  'far hardest',
#  'fast',
#  'fast curve',
#  'faster',
#  'faster go',
#  'feature',
#  'feature walkenhorst',
#  'fed',
#  'fed gran',
#  'feel',
#  'feel comfortable',
#  'feel team',
#  'feeling',
#  'feeling three',
#  'fia',
#  'fighter',
#  'fighter people',
#  'figure',
#  'find',
#  'find really',
#  'find surprising',
#  'finding',
#  'finding best',
#  'finding development',
#  'fire',
#  'fire rocket',
#  'fired',
#  'first',
#  'first gran',
#  'first imagined',
#  'first learn',
#  'first time',
#  'fit',
#  'fit really',
#  'flag',
#  'flare',
#  'flare gun',
#  'flip',
#  'flip flop',
#  'flop',
#  'flop short',
#  'flow',
#  'flow towards',
#  'focus',
#  'focus moment',
#  'foil',
#  'foil car',
#  'ford',
#  'ford club',
#  'forward',
#  'front',
#  'front back',
#  'front stuff',
#  'fun',
#  'fun work',
#  'function',
#  'fur',
#  'fur coat',
#  'gain',
#  'gain experience',
#  'gain one',
#  'gaining',
#  'gaining experience',
#  'game',
#  'game big',
#  'game really',
#  'gamer',
#  'gamer know',
#  'gamers',
#  'general',
#  'general atmosphere',
#  'general mentioned',
#  'general rehearsal',
#  'generally',
#  'generally wider',
#  'generation',
#  'generation vehicle',
#  'george',
#  'george switch',
#  'german',
#  'german automotive',
#  'germany',
#  'germany related',
#  'get',
#  'get car',
#  'get drive',
#  'get eifel',
#  'get nordschleife',
#  'get really',
#  'given',
#  'given car',
#  'go',
#  'god',
#  'god many',
#  'going',
#  'going experience',
#  'going see',
#  'gonna',
#  'gonna end',
#  'good',
#  'good impression',
#  'goose',
#  'goose bump',
#  'got',
#  'got really',
#  'got technical',
#  'grain',
#  'grain luck',
#  'gran',
#  'gran turismo',
#  'great',
#  'great engine',
#  'great feeling',
#  'grid',
#  'grid saturday',
#  'gt',
#  'gt class',
#  'gt production',
#  'gun',
#  'gun fired',
#  'guy',
#  'guy super',
#  'hanging',
#  'hanging around',
#  'happy',
#  'happy say',
#  'hardest',
#  'hardest race',
#  'hero',
#  'homologated',
#  'homologated subsequently',
#  'hour',
#  'hour hour',
#  'hour latest',
#  'hour long',
#  'hour material',
#  'hour time',
#  'huge',
#  'huge air',
#  'hundred',
#  'hundred change',
#  'hundred thousand',
#  'identical',
#  'identical race',
#  'imagine',
#  'imagine always',
#  'imagine going',
#  'imagined',
#  'important',
#  'important also',
#  'important exists',
#  'important know',
#  'important need',
#  'important take',
#  'important thing',
#  'impression',
#  'improvement',
#  'improvement vehicle',
#  'incredible',
#  'incredibly',
#  'incredibly clear',
#  'indeed',
#  'indeed know',
#  'inside',
#  'inside car',
#  'intake',
#  'intake front',
#  'intensively',
#  'intensively finding',
#  'interesting',
#  'interesting also',
#  'interesting experience',
#  'international',
#  'international stage',
#  'involved',
#  'involved technician',
#  'jawbreaker',
#  'jawbreaker done',
#  'job',
#  'job developed',
#  'job guy',
#  'kazunori',
#  'kazunori driving',
#  'kazunori one',
#  'kilometer',
#  'kilometer gaining',
#  'kind',
#  'kind create',
#  'kind general',
#  'kind place',
#  'kind tickling',
#  'kinematics',
#  'kinematics longer',
#  'km',
#  'know',
#  'know beforehand',
#  'know god',
#  'know great',
#  'know people',
#  'know real',
#  'know really',
#  'know understand',
#  'kraemer',
#  'kuhnke',
#  'kuhnke travelling',
#  'lap',
#  'lap afterwards',
#  'lap driver',
#  'lap feel',
#  'lap know',
#  'lap somehow',
#  'lap take',
#  'lap time',
#  'large',
#  'larger',
#  'larger development',
#  'last',
#  'last year',
#  'latest',
#  'latest around',
#  'layout',
#  'layout track',
#  'learn',
#  'learn work',
#  'leash',
#  'least',
#  'least come',
#  'least requirement',
#  'left',
#  'left right',
#  'length',
#  'length km',
#  'let',
#  'let say',
#  'level',
#  'level difficult',
#  'light',
#  'light party',
#  'like',
#  'like community',
#  'like know',
#  'like many',
#  'like movie',
#  'like prepare',
#  'like simulator',
#  'like something',
#  'line',
#  'line like',
#  'little',
#  'little everyone',
#  'lively',
#  'lively exchange',
#  'logger',
#  'logger also',
#  'lone',
#  'lone fighter',
#  'long',
#  'long really',
#  'long straight',
#  'longer',
#  'longer corner',
#  'longer tied',
#  'longer wheelbase',
#  'look',
#  'look series',
#  'look telemetry',
#  'looked',
#  'looked like',
#  'lot',
#  'lot fun',
#  'lot pressure',
#  'lot young',
#  'loud',
#  'loud clear',
#  'love',
#  'love whole',
#  'low',
#  'low battery',
#  'luck',
#  'made',
#  'made pc',
#  'mainly',
#  'mainly differentiated',
#  'major',
#  'major appeal',
#  'make',
#  'make good',
#  'make sure',
#  'make video',
#  'man',
#  'manager',
#  'manager directly',
#  'manufacturer',
#  'many',
#  'many respect',
#  'many thing',
#  'map',
#  'map map',
#  'massive',
#  'massive track',
#  'match',
#  'match properly',
#  'match sens',
#  'material',
#  'material also',
#  'matias',
#  'matias drive',
#  'matias radio',
#  'maximum',
#  'maximum performance',
#  'mean',
#  'mean continuous',
#  'mean everything',
#  'mean kind',
#  'mean vehicle',
#  'mecca',
#  'mecca car',
#  'mechanical',
#  'mechanical beauty',
#  'mechanically',
#  'mechanically aerodynamically',
#  'mentioned',
#  'mentioned current',
#  'midday',
#  'midday see',
#  'might',
#  'might well',
#  'minute',
#  'minute minute',
#  'minute obviously',
#  'modern',
#  'modern day',
#  'modify',
#  'modify near',
#  'moment',
#  'morning',
#  'morning hour',
#  'motivated',
#  'motivated brings',
#  'motor',
#  'motor sport',
#  'motorsport',
#  'motorsport team',
#  'movement',
#  'movement car',
#  'movement track',
#  'movie',
#  'movie believe',
#  'much',
#  'much downforce',
#  'much experience',
#  'near',
#  'near close',
#  'near series',
#  'nearly',
#  'nearly unable',
#  'need',
#  'need certain',
#  'need gain',
#  'new',
#  'new foil',
#  'new generation',
#  'new regulation',
#  'new say',
#  'night',
#  'night stint',
#  'nonetheless',
#  'nonetheless everyone',
#  'nordschleife',
#  'nordschleife night',
#  'norm',
#  'normal',
#  'normal vln',
#  'nothing',
#  'nowadays',
#  'nowadays everything',
#  'nowhere',
#  'nowhere near',
#  'number',
#  'number sensor',
#  'obscure',
#  'obscure place',
#  'obviously',
#  'occasion',
#  'occasion call',
#  'occupied',
#  'occupied intensively',
#  'offered',
#  'offered certain',
#  'ok',
#  'ok take',
#  'okay',
#  'okay matias',
#  'okay start',
#  'one',
#  'one also',
#  'one childhood',
#  'one hardest',
#  'one lap',
#  'one thing',
#  'opel',
#  'opel club',
#  'operating',
#  'operating working',
#  'optimally',
#  'optimally prepared',
#  'originated',
#  'package',
#  'paddock',
#  'paddock point',
#  'part',
#  'part playstation',
#  'part search',
#  'participate',
#  'participate possible',
#  'participating',
#  'participating vln',
#  'particular',
#  'particular special',
#  'partner',
#  'partner dunlop',
#  'party',
#  'past',
#  'pc',
#  'pc like',
#  'people',
#  'people connected',
#  'people feel',
#  'people nearly',
#  'people operating',
#  'people towards',
#  'people watching',
#  'perfect',
#  'perfect lap',
#  'performance',
#  'performance demand',
#  'permitted',
#  'permitted side',
#  'personally',
#  'personally find',
#  'photographer',
#  'physical',
#  'physical design',
#  'pit',
#  'pit analyzed',
#  'pixel',
#  'pixel come',
#  'place',
#  'place adult',
#  'place automobile',
#  'place german',
#  'place still',
#  'place track',
#  'place used',
#  'played',
#  'played hour',
#  'playstation',
#  'playstation car',
#  'playstation gran',
#  'point',
#  'point going',
#  'point view',
#  'porsche',
#  'porsche club',
#  'position',
#  'possible',
#  'possible event',
#  'practically',
#  'prepare',
#  'prepare everything',
#  'prepare nothing',
#  'prepared',
#  'prepared race',
#  'presence',
#  'presence paddock',
#  'pressure',
#  'prestige',
#  'prestige race',
#  'pretty',
#  'pretty identical',
#  'pretty special',
#  'probably',
#  'probably imagine',
#  'probably interesting',
#  'process',
#  'process look',
#  'product',
#  'product car',
#  'product tire',
#  'production',
#  'production engine',
#  'profile',
#  'profile tire',
#  'properly',
#  'pull',
#  'pull direction',
#  'pull leash',
#  'put',
#  'put lot',
#  'qualifying',
#  'qualifying identical',
#  'qualifying race',
#  'quite',
#  'quite beyond',
#  'race',
#  'race extremely',
#  'race get',
#  'race gonna',
#  'race probably',
#  'race really',
#  'race see',
#  'race team',
#  'race worldwide',
#  'racing',
#  'racing car',
#  'racing hundred',
#  'racing think',
#  'radio',
#  'radio check',
#  'rare',
#  'rare occasion',
#  'rburgring',
#  'rburgring particular',
#  'rburgring think',
#  'reach',
#  'reacts',
#  'reacts differently',
#  'real',
#  'real car',
#  'real thing',
#  'real time',
#  'really',
#  'really amount',
#  'really beautiful',
#  'really close',
#  'really connection',
#  'really everything',
#  'really experiencing',
#  'really fallen',
#  'really focus',
#  'really important',
#  'really interesting',
#  'really like',
#  'really rare',
#  'really really',
#  'really sitting',
#  'really special',
#  'really strong',
#  'really well',
#  'rear',
#  'rear wing',
#  'reasonably',
#  'reasonably cost',
#  'received',
#  'received real',
#  'recognize',
#  'recognize corner',
#  'recommend',
#  'recommend anyone',
#  'recorded',
#  'recorded data',
#  'reel',
#  'reel kilometer',
#  'reeling',
#  'reeling kilometer',
#  'reflects',
#  'reflects strongly',
#  'regulation',
#  'regulation gt',
#  'rehearsal',
#  'rehearsal team',
#  'related',
#  'related would',
#  'relatively',
#  'relatively new',
#  'reliability',
#  'reliability simply',
#  'remember',
#  'remember think',
#  'requirement',
#  'requirement profile',
#  'requires',
#  'requires grain',
#  'respect',
#  'respect gamers',
#  'right',
#  'robust',
#  'robust well',
#  'rocket',
#  'rocket flare',
#  'rocket light',
#  'rubber',
#  'rubber boot',
#  'rule',
#  'rule qualifying',
#  ...]

# %%
neg_matrix = cvector.transform(corpus)
neg_words = neg_matrix.sum(axis=0)
neg_words_freq = [(word, neg_words[0, idx]) for word, idx in cvector.vocabulary_.items()]
word_freq = pd.DataFrame(list(sorted(neg_words_freq, key = lambda x: x[1], reverse=True)),columns=['Terms','term_count'])
word_freq.head()
# Out:
#               Terms  term_count
# 0      gran turismo           5
# 1  really important           3
# 2          gt class           3
# 3        racing car           3
# 4       radio check           2
